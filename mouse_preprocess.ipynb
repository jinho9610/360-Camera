# %%
from helpers import *
import matplotlib.pyplot as plt
import os, glob, cv2, random
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Preview

# %%
base_path = 'dataset'

X, y = read_csv(os.path.join(base_path, 'mouse_info.csv'))

print(X.shape, y.shape)
# Out:
# (13752, 26, 34, 1) (13752, 1)

# %%
plt.figure(figsize=(12, 10))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.axis('off')
    plt.imshow(X[i].reshape((26, 34)), cmap='gray')

# %%
sns.distplot(y, kde=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preprocessing

# %%
n_total = len(X)
X_result = np.empty((n_total, 26, 34, 1))

for i, x in enumerate(X):
    img = x.reshape((26, 34, 1))
    
    X_result[i] = img

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(X_result, y, test_size=0.1)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)

np.save('dataset/x_train.npy', x_train)
np.save('dataset/y_train.npy', y_train)
np.save('dataset/x_val.npy', x_val)
np.save('dataset/y_val.npy', y_val)
# Out:
# (12376, 26, 34, 1) (12376, 1)
# (1376, 26, 34, 1) (1376, 1)

# %%
plt.subplot(2, 1, 1)
plt.title(str(y_train[0]))
plt.imshow(x_train[0].reshape((26, 34)), cmap='gray')
plt.subplot(2, 1, 2)
plt.title(str(y_val[4]))
plt.imshow(x_val[4].reshape((26, 34)), cmap='gray')

# %%
sns.distplot(y_train, kde=False)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(y_val, kde=False)
# Out:
# <AxesSubplot:>
